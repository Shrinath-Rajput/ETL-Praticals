# %%
#Install Package and check 

import mysql.connector
print("MySQL Driver Installed Successfully")
# Out:
# MySQL Driver Installed Successfully

# %%
#Connect Database Without Database  

# import mysql.connector as myconn

# conn = myconn.connect(
#     host="localhost",
#     user="root",
#     password="shrinath1814"
# )

# print("Connected Successfully")
# Out:
# Connected Successfully

# %%
#Create Databse 

# cursor = conn.cursor()

# cursor.execute("CREATE DATABASE pratical_databases")

# print("Database Created Successfully")
# Out:
# Database Created Successfully

# %%
#Connect database with database

conn = myconn.connect(
    host="localhost",
    user="root",
    password="shrinath1814",
    # database="pratical_databases"
)

print("Connected to Database Successfully")
# Out:
# Connected to Database Successfully

# %%
cursor = conn.cursor()

# %%
##Create Database 

cursor.execute("CREATE DATABASE pratical_databases_sql")

print("Database Created Successfully")
# Out:
# Database Created Successfully

# %%
cursor.execute("SHOW DATABASES")

for db in cursor:
    print(db)
# Out:
# ('bankdb',)
# ('information_schema',)
# ('mysql',)
# ('performance_schema',)
# ('pratical_databases',)
# ('pratical_databases1',)
# ('pratical_databases_sql',)
# ('sys',)
